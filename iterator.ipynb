# %% [markdown]
# ## Python High-end player

# %%
from itertools import product
import numpy as np

# %%
'''
JobIterator

Documents from Andrew H. Fagg

Translate a dictionary containing parameter/list pairs (key/value) into a Cartesian product
of all combinations of possible parameter values.  

Internally, the Cartesian product is stored as a list of dictionaries (parameter/value pairs).  
This class allows for indexed access to this list.  In addition the values of a particular element
of the list can be added to the property list of an existing object.

Example:
# Dictionary of possible parameter values
p = {'rotation': range(20),
     'Ntraining': [1,2,3,5,10,18],
     'dropout': [None, .1, .2, .5]}

# Create job iterator
ji = JobIterator(p)

# Select the ith element of the Cartesian product list.
# Add properties to object obj; the names of these  properties
#  are the keys from p and the values are the specific combination
#  of values in the ith element
ji.set_attributes_by_index(i, obj)
            
'''

# %%
class JobIterator():
    
    
    def __init__(self,params):
        '''
        Constructor
        
        @param params Dictionary of key/list pairs
        '''
        self.params = params
        self.product = list(dict(zip(params,x))for x in product(*params.values()))
        self.iter = (dict(zip(params,x))for x in product(*params.values()))
    def __iter__(self):
        return self
    
    def __next__(self):
        '''
        @return The next combination in the list
        '''
        return self.next()
    def get_index(self,i):
        '''
        Return the ith combination of parameters
        
        @param i Index into the Cartesian product list
        @return The ith combination of parameters
        '''
        return self.product[i]
    def get_njobs(self):
        '''
        @return The total number of combinationss
        '''
        return len(self.product)
    def set_attributes_by_index(self,i,obj):
         '''
        For an arbitrary object, set the attributes to match the ith job parameters
        
        @param i Index into the Cartesian product list
        @param obj Arbitrary object (to be modified)
        '''
        
        # For an arbitrary object, set the attributes to match the ith job parameters
        d = self.get_index(i)
        for k,v in d.items():
            setattr(obj,k,v)

# %% [markdown]
# ## Test

# %%
p = {'rotation':range(20),'Ntraining':[1,2,3,5,10,15],'L2_regularizer':[None, .1,.01,.001]}

# %%
type(p)
# Out:
# dict

# %%
ji = JobIterator(p)

# %%
print('total jobs:',ji.get_njobs())

# %%
ji.product
# Out:
# [{'rotation': 0, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 0, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 0, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 0, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 0, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 0, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 0, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 0, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 0, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 1, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 1, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 1, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 1, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 2, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 2, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 2, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 2, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 3, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 3, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 3, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 3, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 4, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 4, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 4, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 4, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 5, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 5, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 5, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 5, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 6, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 6, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 6, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 6, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 7, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 7, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 7, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 7, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 8, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 8, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 8, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 8, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 9, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 9, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 9, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 9, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 10, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 10, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 10, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 10, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 11, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 11, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 11, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 11, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 12, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 12, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 12, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 12, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 13, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 13, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 13, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 13, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 14, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 14, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 14, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 14, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 15, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 15, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 15, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 15, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 16, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 16, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 16, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 16, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 17, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 17, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 17, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 17, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 18, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 18, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 18, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 18, 'Ntraining': 15, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 1, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 1, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 1, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 1, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 2, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 2, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 2, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 2, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 3, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 3, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 3, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 3, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 5, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 5, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 5, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 5, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 10, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 10, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 10, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 10, 'L2_regularizer': 0.001},
#  {'rotation': 19, 'Ntraining': 15, 'L2_regularizer': None},
#  {'rotation': 19, 'Ntraining': 15, 'L2_regularizer': 0.1},
#  {'rotation': 19, 'Ntraining': 15, 'L2_regularizer': 0.01},
#  {'rotation': 19, 'Ntraining': 15, 'L2_regularizer': 0.001}]

# %%
class Person:
    name = 'Adam'
m = Person()

# %%
m.name

# %%
ji.get_index(8).items()
# Out:
# dict_items([('rotation', 0), ('Ntraining', 3), ('L2_regularizer', None)])

# %%
for k,v in ji.get_index(8).items():
    setattr(m,k,v)

# %%
    
m.L2_regularizer

# %%
print(ji.set_attributes_by_index(8,m))
# Out:
# None
